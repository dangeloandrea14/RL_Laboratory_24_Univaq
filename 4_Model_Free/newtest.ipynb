# %%
from env import env
from agent import agent
import utils
from tqdm import tqdm
import networkx as nx
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import numpy as np
from IPython.display import HTML
from matplotlib.ticker import MaxNLocator
from matplotlib.colors import LogNorm

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Model-free
#
# This time, we don't know the environment. We need to compute an estimate of the optimal policy.

# %% [markdown]
# If all trajectories are finite:
# 1. sample a set of finite trajectories (arrive at termination state);
# 2. average returns;

# %% [markdown]
# These are the AGENT'S POLICIES. The Probability matrix of the environment does not have anything to do with these.

# %%
def policy_function_right(state):
    return 'right'

def policy_function_left(state):
    return 'left'

def policy_function_to_extremes(state):
    return 'left' if state.number <= 3 else 'right'

def policy_function_to_middle(state):
    return 'left' if state.number >3 else 'right'

# %%
agent = agent(policy_function_right)

# %%
utils.visualize_policy(agent.my_env,agent)

# %%
agent.my_env.states

# %%
agent.easy_policy
# Out:
# {3: 'right'}

# %%
colors = ['red', 'green', 'blue', 'yellow', 'orange', 'purple', 'brown', 'pink']

for i in range(len(colors)):
    episode = agent.sample_episode(10, random_first_state=True)  
    print(episode)
    time_steps = range(1, len(episode) + 1)
    plt.plot(episode, time_steps, marker='o', linestyle='-', color=colors[i])

plt.xlabel('State')
plt.ylabel('Time Step')
plt.xticks(np.arange(0, 8, step=1))
plt.title('Agent Movement Over Time')
plt.grid(True)
# Out:
# [3, 3, 3, 3, 3, 4, 5, 6, 6, 6]
# [6, 6, 6, 6, 6, 6, 6, 6, 6, 6]
# [3, 4, 5, 5, 6, 6, 6, 6, 6, 6]
# [3, 4, 5, 6, 6, 6, 6, 6, 6, 6]
# [5, 6, 6, 6, 6, 6, 6, 6, 6, 6]
# [6, 6, 6, 6, 6, 6, 6, 6, 6, 6]
# [3, 4, 5, 6, 6, 6, 6, 6, 6, 6]
# [5, 6, 6, 6, 6, 6, 6, 6, 6, 6]

# %% [markdown]
# Let's try making a step.

# %%
agent.step().name
# Out:
# 'right'

# %%
agent.make_step(   agent.step()      ).number
# Out:
# 3

# %%
agent.easy_policy
# Out:
# {3: 'right', 4: 'right', 5: 'right', 6: 'right'}

# %%
[state.number for state in agent.my_env.states]
# Out:
# [3, 4, 5, 6]

# %%
agent.sample_episode(10)
# Out:
# [3, 3, 4, 5, 6, 6, 6, 6, 6, 6]

# %%
agent.reset_state()

# %%
agent.evaluate_policy_first_visit_montecarlo(1000)
# Out:
# {3: 0.712109375,
#  4: 2.0171984594188377,
#  5: 5.852612652749491,
#  6: 18.18186532079646}

# %%
agent.evaluate_policy_every_visit_montecarlo(1000)
# Out:
# {3: 0.7027261995916284,
#  4: 2.0202348845960865,
#  5: 5.916523972602739,
#  6: 15.99218565001184}

# %%
agent.evaluate_policy_incremental(1000)
# Out:
# {3: 0.7030353156887765,
#  4: 2.0185688973908635,
#  5: 5.8336316830332775,
#  6: 16.007838455149443}

# %%
colors = ['red', 'green', 'blue', 'yellow', 'orange', 'purple', 'brown', 'pink']

for i in range(len(colors)):
    episode = agent.sample_episode(10, random_first_state=True)  
    time_steps = range(1, len(episode) + 1)
    plt.plot(episode, time_steps, marker='o', linestyle='-', color=colors[i])

plt.xlabel('State')
plt.ylabel('Time Step')
plt.xticks(np.arange(0, 8, step=1))
plt.title('Agent Movement Over Time')
plt.grid(True)

# %% [markdown]
# ## Policy Improvement

# %%
agent.improve_policy()
# Out:
# {(3, 'left'): 0.1904296875, (3, 'right'): 0.44227233013654094, (4, 'left'): 0.6080078125, (4, 'right'): 1.4484943674176776, (5, 'left'): 2.0986328125, (5, 'right'): 5.241847264332966, (6, 'left'): 17.1109375, (6, 'right'): 16.7537900135257, (2, 'left'): 0.059382891414141416, (2, 'right'): 0.13214936127533783, (1, 'left'): 301767.6966934975, (1, 'right'): 0.0387253668009206, (0, 'left'): 1674835.5324835526, (0, 'right'): 1344151.8868553883}
# {(3, 'left'): 0,
#  (3, 'right'): 1,
#  (4, 'left'): 0,
#  (4, 'right'): 1,
#  (5, 'left'): 0,
#  (5, 'right'): 1,
#  (6, 'left'): 1,
#  (6, 'right'): 0,
#  (2, 'left'): 0,
#  (2, 'right'): 1,
#  (1, 'left'): 1,
#  (1, 'right'): 0,
#  (0, 'left'): 1,
#  (0, 'right'): 0}

# %%
agent.easy_policy
# Out:
# {3: 'right',
#  4: 'right',
#  5: 'right',
#  6: 'left',
#  2: 'right',
#  1: 'left',
#  0: 'left'}

# %%
for i in range(10):
    agent.improve_policy()
# Out:
# {(3, 'left'): 0.20546875, (3, 'right'): 0.5013528326837416, (4, 'left'): 0.6037109375, (4, 'right'): 1.4162139892578125, (5, 'left'): 1.784375, (5, 'right'): 3.7858908925227395, (6, 'left'): 14.194270542689733, (6, 'right'): 11.22341579861111, (2, 'left'): 150839.902734375, (2, 'right'): 0.1634478519668737, (1, 'left'): 659793.1690705129, (1, 'right'): 156598.11262376237, (0, 'left'): 1865750.8131153304, (0, 'right'): 1139008.0686475409}
# {(3, 'left'): 38047.0021484375, (3, 'right'): 0.5086027817919075, (4, 'left'): 0.5603515625, (4, 'right'): 1.4833020950112108, (5, 'left'): 1.5404296875, (5, 'right'): 3.8540453059230306, (6, 'left'): 14.25271602769972, (6, 'right'): 11.448372521760154, (2, 'left'): 200673.7889056225, (2, 'right'): 52678.149601862984, (1, 'left'): 614387.1585264901, (1, 'right'): 212034.97023809524, (0, 'left'): 1848315.4831099561, (0, 'right'): 1100685.586734694}
# {(3, 'left'): 62184.380941064635, (3, 'right'): 11680.1591796875, (4, 'left'): 16953.514453125, (4, 'right'): 1.464916492085661, (5, 'left'): 0.3849836923543689, (5, 'right'): 4.302376195004112, (6, 'left'): 13.723252927698574, (6, 'right'): 17.45078125, (2, 'left'): 185370.6376061571, (2, 'right'): 63105.46875, (1, 'left'): 608143.328826955, (1, 'right'): 215683.59375, (0, 'left'): 1707139.0031160605, (0, 'right'): 1673125.0}
# {(3, 'left'): 55504.48034429599, (3, 'right'): 27343.75, (4, 'left'): 15561.514101338433, (4, 'right'): 4435.1357421875, (5, 'left'): 4410.611270111386, (5, 'right'): 6.62733843537415, (6, 'left'): 11.44103499483471, (6, 'right'): 18.67186124075379, (2, 'left'): 181112.3454404946, (2, 'right'): 79570.3125, (1, 'left'): 562690.1159961064, (1, 'right'): 194921.875, (0, 'left'): 1688195.230015083, (0, 'right'): 1651796.875}
# {(3, 'left'): 48823.25436408978, (3, 'right'): 31933.59375, (4, 'left'): 15225.75493612079, (4, 'right'): 8574.21875, (5, 'left'): 4862.800973360656, (5, 'right'): 532.6333984375, (6, 'left'): 529.0034535389073, (6, 'right'): 18.826303904428904, (2, 'left'): 163550.5769851517, (2, 'right'): 81289.0625, (1, 'left'): 534114.5833333334, (1, 'right'): 229296.875, (0, 'left'): 1677944.0445323873, (0, 'right'): 1622578.125}
# {(3, 'left'): 39389.99848116646, (3, 'right'): 23730.46875, (4, 'left'): 11513.241741435562, (4, 'right'): 5722.65625, (5, 'left'): 3065.2016795154186, (5, 'right'): 2073.878125, (6, 'left'): 771.8775153882576, (6, 'right'): 328.9716796875, (2, 'left'): 144203.2788071801, (2, 'right'): 55625.0, (1, 'left'): 507793.2468510405, (1, 'right'): 247460.9375, (0, 'left'): 1676704.1275969849, (0, 'right'): 1664921.875}
# {(3, 'left'): 42963.873283395755, (3, 'right'): 18769.53125, (4, 'left'): 12589.610258481422, (4, 'right'): 5878.90625, (5, 'left'): 4126.444475760992, (5, 'right'): 1507.8078125, (6, 'left'): 1274.7943300189395, (6, 'right'): 680.830859375, (2, 'left'): 145965.16059798698, (2, 'right'): 67675.78125, (1, 'left'): 502204.0328491471, (1, 'right'): 237597.65625, (0, 'left'): 1676318.0029653285, (0, 'right'): 1636640.625}
# {(3, 'left'): 45601.45187120701, (3, 'right'): 27539.0625, (4, 'left'): 13361.33629707113, (4, 'right'): 7753.90625, (5, 'left'): 3276.9564924568967, (5, 'right'): 1644.1546875, (6, 'left'): 851.6928314035916, (6, 'right'): 680.68671875, (2, 'left'): 154769.05906593407, (2, 'right'): 77636.71875, (1, 'left'): 527655.1797945206, (1, 'right'): 201171.875, (0, 'left'): 1675197.1573694528, (0, 'right'): 1706191.40625}
# {(3, 'left'): 36472.093791281375, (3, 'right'): 17031.25, (4, 'left'): 11304.260450160771, (4, 'right'): 5488.28125, (5, 'left'): 3669.7123702422145, (5, 'right'): 2346.825, (6, 'left'): 1087.6227313045852, (6, 'right'): 543.933984375, (2, 'left'): 121934.6476750861, (2, 'right'): 56601.5625, (1, 'left'): 347710.76231512404, (1, 'right'): 172460.9375, (0, 'left'): 1117668.7947138315, (0, 'right'): 1406535.09667756}
# {(3, 'left'): 32522.52837276215, (3, 'right'): 20351.5625, (4, 'left'): 9436.598557692309, (4, 'right'): 5078.125, (5, 'left'): 2474.698153409091, (5, 'right'): 687.071875, (6, 'left'): 655.6853768577495, (6, 'right'): 563.3515625, (2, 'left'): 119008.1153791334, (2, 'right'): 54785.15625, (1, 'left'): 364104.91015330487, (1, 'right'): 187656.25, (0, 'left'): 1116113.7440758294, (0, 'right'): 1424313.8080879746}

# %%
agent.easy_policy
# Out:
# {3: 'left', 4: 'left', 5: 'left', 6: 'left', 2: 'left', 1: 'left', 0: 'right'}

# %%
colors = ['red', 'green', 'blue', 'yellow', 'orange', 'purple', 'brown', 'pink']

for i in range(len(colors)):
    episode = agent.sample_episode(10, random_first_state = True)  
    time_steps = range(1, len(episode) + 1)
    plt.plot(episode, time_steps, marker='o', linestyle='-', color=colors[i])

plt.xlabel('State')
plt.ylabel('Time Step')
plt.xticks(np.arange(0, 8, step=1))
plt.title('Agent Movement Over Time')
plt.grid(True)
